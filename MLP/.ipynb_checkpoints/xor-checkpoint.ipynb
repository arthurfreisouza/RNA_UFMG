# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import time
import matplotlib.animation

# %%
def sech2(x):
    y = np.array(2 / (np.exp(x) + np.exp(-x))) * np.array(2 / (np.exp(x) + np.exp(-x)))
    return y

# %%
x = np.array((0, 0, 0, 1, 1, 0, 1, 1)).reshape(4, 2)
y = np.array((-1, 1, 1, -1, 1, -1, -1, 1)).reshape(4, 2)
print(f" Inputs : \n{x}. \n Labels : \n{y}.")
# Out:
#  Inputs :
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]].
#  Labels :
# [[-1  1]
#  [ 1 -1]
#  [ 1 -1]
#  [-1  1]].

# %%
wb11 = np.random.random(1) - 0.5
wb12 = np.random.random(1) - 0.5

wipt11 = np.random.random(1) - 0.5
wipt12 = np.random.random(1) - 0.5

wipt21 = np.random.random(1) - 0.5
wipt22 = np.random.random(1) - 0.5

print(f"Bias : ({wb11}, {wb12}). \n First Input : ({wipt11}, {wipt12}). \n Second Input : ({wipt21}, {wipt21}).")
# Out:
# Bias : ([-0.27702891], [-0.45406474]).
#  First Input : ([-0.00228636], [-0.24276255]).
#  Second Input : ([-0.13149507], [-0.13149507]).

# %%
np.random.seed(np.random.randint(0, 10000))
wb21 = np.random.random(1) - 0.5
wb22 = np.random.random(1) - 0.5

wipt11_2 = np.random.random(1) - 0.5
wipt12_2 = np.random.random(1) - 0.5

wipt21_2 = np.random.random(1) - 0.5
wipt22_2 = np.random.random(1) - 0.5

print(f"Bias : ({wb21}, {wb22}). \n First Last Neuron Input : ({wipt11_2}, {wipt12_2}). \n Second Last Neuron Input : ({wipt21_2}, {wipt22_2}).")
# Out:
# Bias : ([0.23868647], [0.01602349]).
#  First Last Neuron Input : ([0.15442743], [-0.42623919]).
#  Second Last Neuron Input : ([0.06505517], [-0.42495375]).

# %%
num_epochs = 0
tol = 0.1
err_epochs = tol + 1
max_epochs = 100
N = 4 # Número de entradas.
eta = 0.01 # Learning_rate.
err_vec = np.zeros(max_epochs)

# %%
matH = np.zeros((N, 2))

# %%
sequence = np.arange(start = 0, stop = N, step = 1).tolist()
seq_randomized = random.sample(population = sequence, k = N)
seq_randomized
out_n1 = np.zeros((max_epochs * N)).reshape(-1, N)
out_n2 = np.zeros((max_epochs * N)).reshape(-1, N)

# %%
while((num_epochs < max_epochs) and (err_epochs > tol)):
    sequence = np.arange(start = 0, stop = N, step = 1).tolist()
    seq_randomized = random.sample(population = sequence, k = N)
    err2 = 0
    for i in range(N):
        # Pegando entradas aleatórias.
        rand_input = seq_randomized[i]
        input1 = x[rand_input, 0]
        input2 = x[rand_input, 1]


        # Pegando as saídas das entradas aleatórias.
        output1 = y[rand_input, 0]
        output2 = y[rand_input, 1]

        # Inicializando o valor dos biases da camada de entrada e da camada de saída.
        bias1 = 1
        bias2 = 1


        # Fazendo a combinação linear dos dois neurônios de saída e aplicando a função de ativação sigmoidal.
        cl1 = (bias1*wb11) + (input1*wipt11) + (input2*wipt21)
        cl2 = (bias1*wb12) + (input1*wipt12) + (input2*wipt22)
        tanh_n1 = np.tanh(cl1)
        tanh_n2 = np.tanh(cl2)



        # Fazendo a combinação linear dos dois neutônios de entrada e aplicando a função de ativação sigmoidal.
        comb_n11 = (bias2*wb21) + (tanh_n1*wipt11_2) + (tanh_n2*wipt21_2)
        comb_n22 = (bias2*wb22) + (tanh_n1*wipt12_2) + (tanh_n2*wipt22_2)
        tanh_n11 = np.tanh(comb_n11)
        tanh_n22 = np.tanh(comb_n22)

        matH[rand_input, 0] = tanh_n11
        matH[rand_input, 1] = tanh_n22
        

        # Calculo do erro e a retropropagação dos erros.
        err_output1 = (output1 - tanh_n11)
        err_output2 = (output2 - tanh_n22)
        delta_output1 = err_output1*sech2(comb_n11) # Lembrar que delta(N) = e*f'(u) SEMPRE.
        delta_output2 = err_output2*sech2(comb_n22) # Lembrar que delta(N) = e*f'(u) SEMPRE.



        # Atualização dos pesos : 
        dwbias21 = (eta*delta_output1*bias2) # atualização do peso do bias da camada de saída.
        dwbias22 = (eta*delta_output2*bias2) # atualização do peso do bias da camada de saída.

        
        dwipt_11_2 = (eta*delta_output1*tanh_n1) # atualização do peso do bias da camada de saída.
        dwipt_12_2 = (eta*delta_output2*tanh_n1) # atualização do peso do bias da camada de saída.


        dwipt_21_2 = (eta*delta_output1*tanh_n2) # atualização do peso do bias da camada de saída.
        dwipt_22_2 = (eta*delta_output2*tanh_n2) # atualização do peso do bias da camada de saída.
        
        # Calculando o delta dos neurônios da camada de entrada e a retropropragação da camada de entrada.
        delta_input1 = (delta_output1*wipt11_2 + delta_output2*wipt12_2)*sech2(cl1)
        delta_input2 = (delta_output1*wipt21_2 + delta_output2*wipt22_2)*sech2(cl2)

        dbias11 = eta*delta_input1*bias1
        dbias12 = eta*delta_input2*bias1

        
        dipt11 = eta*delta_input1*input1
        dipt12 = eta*delta_input2*input1

        
        dipt21 = eta*delta_input1*input2
        dipt22 = eta*delta_input2*input2


        # Atualização de todos os pesos da rede.

        wb11 = wb11 + dbias11
        wb12 = wb12 + dbias12

        wipt11 = wipt11 + dipt11
        wipt12 = wipt12 + dipt12

        wipt21 = wipt21 + dipt21
        wipt22 = wipt22 + dipt22

        wb21 = wb21 + dwbias21
        wb22 = wb22 + dwbias22
        
        wipt11_2 = wipt11_2 + dwipt_11_2
        wipt12_2 = wipt12_2 + dwipt_12_2
        
        wipt21_2 = wipt21_2 + dwipt_21_2
        wipt22_2 = wipt22_2 + dwipt_22_2

        err2 = err2 + (err_output1**2 + err_output2)/4
    plt.scatter(matH[0:, 0], matH[0:, 1], color = 'blue')
    plt.scatter(matH[1:, 0], matH[1:, 1], color = 'red')
    plt.scatter(matH[2:, 0], matH[2:, 1], color = 'red')
    plt.scatter(matH[3:, 0], matH[3:, 1], color = 'blue')
    time.sleep(0.1)
    plt.show()
    err_vec[num_epochs] = err2/N
    num_epochs += 1
# Out:
# /tmp/ipykernel_34055/3135324308.py:35: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   matH[rand_input, 0] = tanh_n11
# /tmp/ipykernel_34055/3135324308.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   matH[rand_input, 1] = tanh_n22
# /tmp/ipykernel_34055/3135324308.py:102: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   err_vec[num_epochs] = err2/N

# %%
plt.scatter(matH[0:, 0], matH[0:, 1], color = 'blue')
plt.scatter(matH[1:, 0], matH[1:, 1], color = 'red')
plt.scatter(matH[2:, 0], matH[2:, 1], color = 'red')
plt.scatter(matH[3:, 0], matH[3:, 1], color = 'blue')
plt.show()

# %%
out_n1.shape, out_n2[0, :]

# Agora, para cada uma das 500 linhas do array terei as 4 saídas da rede, basta ṕlotar (0,0), (0,1), (1,0) e (1,1)
# Out:
# ((100, 4), array([0., 0., 0., 0.]))

# %%
x_plot = np.linspace(start = 0, stop = num_epochs, num = num_epochs)
plt.plot(x_plot, err_vec, color = 'black', label = 'err_graphic')
plt.title('Err graphic')
plt.xlabel('num_epochs')
plt.ylabel('err²')
plt.legend()
plt.show()

# %%
for i in range(N):
    c1 = (bias1*wb11) + (x[i, 0]*wipt11) + (x[i, 1]*wipt21)
    c2 = (bias1*wb12) + (x[i, 0]*wipt12) + (x[i, 1]*wipt22)
    tan_c1 = np.tanh(c1)
    tan_c2 = np.tanh(c2)

    co1 = (bias2*wb21) + (tan_c1*wipt11_2) + (tan_c2*wipt21_2)
    co2 = (bias2*wb22) + (tan_c1*wipt12_2) + (tan_c2*wipt22_2)
    print(f"Para a entrada ({x[i,0]}, {x[i,1]}) a saída é ({np.tanh(co1)}, {np.tanh(co2)})")
# Out:
# Para a entrada (0, 0) a saída é ([-0.00093097], [0.00890626])
# Para a entrada (0, 1) a saída é ([0.02307917], [-0.05908583])
# Para a entrada (1, 0) a saída é ([-0.019449], [0.05986327])
# Para a entrada (1, 1) a saída é ([-0.00590297], [0.01671478])

# %%
t = np.arange(start = 0, stop = max_epochs, step = 1)

fig, ax = plt.subplots()
ax.axis([0,2*np.pi,-1,1])
l, = ax.plot([],[])
out_n1
out_n2
def animate(i):
    l.set_data(out_n1[:i], out_n2[:i])
    l.set_data(t[:i], x[:i])

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))

from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[241], line 15
#      12 ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))
#      14 from IPython.display import HTML
# ---> 15 HTML(ani.to_jshtml())
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/animation.py:1353, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1349         path = Path(tmpdir, "temp.html")
#    1350         writer = HTMLWriter(fps=fps,
#    1351                             embed_frames=embed_frames,
#    1352                             default_mode=default_mode)
# -> 1353         self.save(str(path), writer=writer)
#    1354         self._html_representation = path.read_text()
#    1356 return self._html_representation
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import time

# Dados iniciais
x = np.random.rand(10)
y = np.random.rand(10)

# Criar o gráfico inicial
sns.set(style="whitegrid")  # Estilo do gráfico
fig, ax = plt.subplots()
scatter = sns.scatterplot(x=x, y=y)

# Configurações do gráfico
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.title("Gráfico Variável no Tempo")

# Função para atualizar o gráfico
def update_plot():
    # Gerar novos dados
    x_new = np.random.rand(10)
    y_new = np.random.rand(10)
    
    # Limpar o gráfico
    ax.clear()
    
    # Plotar os novos pontos
    sns.scatterplot(x=x_new, y=y_new, ax=ax)
    
    # Configurações do gráfico
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    plt.title("Gráfico Variável no Tempo")
    
    # Forçar a atualização do gráfico
    plt.draw()
    plt.pause(0.1)

# Loop para atualizar o gráfico
for i in range(10):
    update_plot()
    time.sleep(1)  # Pausa de 1 segundo para visualização

plt.show()
