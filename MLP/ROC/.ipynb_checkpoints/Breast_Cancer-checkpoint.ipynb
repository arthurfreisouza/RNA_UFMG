# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
x = pd.DataFrame(data.data, columns = data.feature_names)
y = pd.Series(data.target)
x
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
np.unique(y, return_counts = True)
# Out:
# (array([0, 1]), array([212, 357]))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, random_state =10)

# %%
from sklearn.neural_network import MLPClassifier

# %%
hidden_layer = (50, 1)
clf = MLPClassifier(hidden_layer_sizes = hidden_layer , activation = 'tanh', solver = 'sgd', alpha = 0.01, max_iter = 150, learning_rate = 'adaptive', learning_rate_init = 0.01).fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (150) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
sum_train = sum(y_test != y_pred)
print(f"There are a total of {sum_train} errors in the train.")
# Out:
# There are a total of 2 errors in the train.

# %%
from sklearn.metrics import classification_report
y_pred_class_report = classification_report(y_test, y_pred, target_names=data.target_names)
print(y_pred_class_report)
# Out:
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.97      0.97        39
#       benign       0.99      0.99      0.99        75
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot([0, 1], [0,1], '--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi Layer Perceptron ROC Curve')
plt.show()

# %%
thresholds
# Out:
# array([inf,  1.,  0.])
