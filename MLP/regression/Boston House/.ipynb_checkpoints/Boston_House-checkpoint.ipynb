# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("boston.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.shape
# Out:
# (506, 14)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cond = ['CRIM', 'ZN', 'INDUS', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

df = df.astype(float)
df.loc[:, cond] = scaler.fit_transform(df.loc[:, cond])

# %%
df.head()
# Out:
#        CRIM        ZN     INDUS  CHAS    NOX        RM       AGE       DIS  \
# 0 -0.419782  0.284830 -1.287909   0.0  0.538  0.413672 -0.120013  0.140214
# 1 -0.417339 -0.487722 -0.593381   0.0  0.469  0.194274  0.367166  0.557160
# 2 -0.417342 -0.487722 -0.593381   0.0  0.469  1.282714 -0.265812  0.557160
# 3 -0.416750 -0.487722 -1.306878   0.0  0.458  1.016303 -0.809889  1.077737
# 4 -0.412482 -0.487722 -1.306878   0.0  0.458  1.228577 -0.511180  1.077737
#
#         RAD       TAX   PTRATIO         B     LSTAT  MEDV
# 0 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  24.0
# 1 -0.867883 -0.987329 -0.303094  0.441052 -0.492439  21.6
# 2 -0.867883 -0.987329 -0.303094  0.396427 -1.208727  34.7
# 3 -0.752922 -1.106115  0.113032  0.416163 -1.361517  33.4
# 4 -0.752922 -1.106115  0.113032  0.441052 -1.026501  36.2

# %%
x = df.iloc[:, : -1]
y = df.iloc[:, -1]

# %%
# %%time

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {
    'hidden_layer_sizes': [10, 15, 20, 30, 40, 50, 100]
}

mlp = MLPRegressor(max_iter = 500, early_stopping = True)

mlp_regressor = GridSearchCV(estimator = mlp, param_grid = param_grid, cv = 10).fit(X = x, y = y)

best_mlp_score = mlp_regressor.best_score_
best_mlp_param = mlp_regressor.best_params_
# Out:
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
X_train = np.array(X_train).astype(np.float64)
y_train = np.array(y_train).astype(np.float64)
X_test = np.array(X_test).astype(np.float64)
y_test = np.array(y_test).astype(np.float64)
mlp = MLPRegressor(hidden_layer_sizes = 10, solver = 'sgd', early_stopping = True)
# Out:
#   Cell In[135], line 5
#     mlp = MLPRegressor(hidden_layer_sizes = 10, solver = 'sgd', early stopping = True)
#                                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(best_mlp_param)
# Out:
# {'hidden_layer_sizes': 40}

# %%
from sklearn.model_selection import cross_val_score
lst_scores = list()

for i in range(5):
    df_shuffle = pd.concat([x, y], axis = 1)
    df_shuffle = df_shuffle.sample(frac=1, random_state=42).reset_index(drop=True)
    x = df.iloc[:, : -1]
    y = df.iloc[:, -1]
    lst_scores.append(np.mean(cross_val_score(mlp, x, y, cv=10, scoring = 'neg_mean_squared_error')))

mse_scores = [-score for score in lst_scores]

print(f"The MSE for the test values is {np.mean(mse_scores)}")
# Out:
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/arthur/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
import statistics

print(f"The MSE for the test values is {np.mean(mse_scores)} +- {statistics.stdev(mse_scores)}")
# Out:
# The MSE for the test values is 29.700893845717662 +- 0.5530529840143832
