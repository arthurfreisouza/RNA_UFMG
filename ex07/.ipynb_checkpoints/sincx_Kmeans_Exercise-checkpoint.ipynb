# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_sinc = np.arange(start = -10, stop = 10, step = 0.08)
y_sinc = np.sinc(x_sinc)
y_noise = y_sinc + np.random.normal(loc = 0, scale = 0.05, size = 250)

# %%
plt.scatter(x_sinc, y_noise, color = 'black', s = 5)
plt.title('sinc(x) = (sin(x)/x)')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_sinc, y_noise, random_state = 0, train_size = 0.7)

# %%
from sklearn.cluster import KMeans
X_train = X_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
kmeans = KMeans(n_clusters = 1, random_state = 0, n_init = 'auto').fit(X_train)
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# %%
plt.scatter(X_train, y_train, c=cluster_labels, cmap='viridis', marker='o', edgecolors='k')
plt.scatter(cluster_centers[:, 0], np.zeros((cluster_centers.shape[0])), c='red', marker='x', s=100, label='Cluster Centers')

# Add labels and legend
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KMeans Clustering')
plt.legend()

# Show the plot
plt.show()

# %%
import train_RBF
ret_ = train_RBF.trainRBF(X_train, y_train, cluster_centers.shape[0], 0.6)
# Out:
# H shape : (175, 1)
# Haug shape : (175, 2)
# yin shape : (175, 1)
# W shape : (2, 1)

# %%
W = ret_[3]
W
# Out:
# array([[ 0.73990116],
#        [-0.03270724]])

# %%
yhat_test = train_RBF.y_RBF(X_test, ret_)
yhat_train = train_RBF.y_RBF(X_train, ret_)
# Out:
# You're having the error tuple index out of range. So we will change the numer of dimensions...

# %%
from sklearn.metrics import mean_squared_error
error_train = mean_squared_error(y_train, yhat_train)
error_test = mean_squared_error(y_test, yhat_test)
print(f"The train error is {error_train}")
print(f"The test error is {error_test}")
# Out:
# The train error is 0.016034364133661022
# The test error is 0.02131193262916912

# %%
def radial_n_var(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-(x - mu)**2 / (2 * sigma**2))

# %%
cluster_centers = cluster_centers.reshape(-1, )
def create_graphics(centers : np.ndarray):
    x_seq = np.linspace(start = -10, stop = 10, num = 250)
    for i in centers:
        normal_function = radial_n_var(x_seq, i, 0.6)
        if i == centers[centers.shape[0] - 1]:
            plt.plot(x_seq, normal_function, color = 'blue', label = 'gauss(x)')
            break
        plt.plot(x_seq, normal_function, color = 'blue')
    plt.plot(x_seq, W[0]*np.sinc(x_seq), color = 'red', label = 'sinc(x)')
    plt.legend()

# %%
create_graphics(cluster_centers)  # Plot normal distributions with 5 centers
plt.xlabel('X')
plt.xlim(-15, 15)
plt.ylabel('Y')
plt.title('Normal Distributions')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import accuracy_score
lst_error_test = list()
lst_param = list()
for i in range(1, 200, 1):
    kmeans = KMeans(n_clusters = i, random_state = 0, n_init = 'auto').fit(X_train)
    cluster_labels = kmeans.labels_
    cluster_centers = kmeans.cluster_centers_
    ret_ = train_RBF.trainRBF(X_train, y_train, i, 0.6)
    yhat_test = train_RBF.y_RBF(X_test, ret_)
    
    error_test = mean_squared_error(y_test, yhat_test)
    lst_error_test.append(error_test)
    lst_param.append(i)
lst_error_test = np.array(lst_acc_test)
lst_param = np.array(lst_param)
# Out:
# H shape : (175, 1)
# Haug shape : (175, 2)
# yin shape : (175, 1)
# W shape : (2, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 2)
# Haug shape : (175, 3)
# yin shape : (175, 1)
# W shape : (3, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 3)
# Haug shape : (175, 4)
# yin shape : (175, 1)
# W shape : (4, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 4)
# Haug shape : (175, 5)
# yin shape : (175, 1)
# W shape : (5, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 5)
# Haug shape : (175, 6)
# yin shape : (175, 1)
# W shape : (6, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 6)
# Haug shape : (175, 7)
# yin shape : (175, 1)
# W shape : (7, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 7)
# Haug shape : (175, 8)
# yin shape : (175, 1)
# W shape : (8, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 8)
# Haug shape : (175, 9)
# yin shape : (175, 1)
# W shape : (9, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 9)
# Haug shape : (175, 10)
# yin shape : (175, 1)
# W shape : (10, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 10)
# Haug shape : (175, 11)
# yin shape : (175, 1)
# W shape : (11, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 11)
# Haug shape : (175, 12)
# yin shape : (175, 1)
# W shape : (12, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 12)
# Haug shape : (175, 13)
# yin shape : (175, 1)
# W shape : (13, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 13)
# Haug shape : (175, 14)
# yin shape : (175, 1)
# W shape : (14, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 14)
# Haug shape : (175, 15)
# yin shape : (175, 1)
# W shape : (15, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 15)
# Haug shape : (175, 16)
# yin shape : (175, 1)
# W shape : (16, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 16)
# Haug shape : (175, 17)
# yin shape : (175, 1)
# W shape : (17, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 17)
# Haug shape : (175, 18)
# yin shape : (175, 1)
# W shape : (18, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 18)
# Haug shape : (175, 19)
# yin shape : (175, 1)
# W shape : (19, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 19)
# Haug shape : (175, 20)
# yin shape : (175, 1)
# W shape : (20, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 20)
# Haug shape : (175, 21)
# yin shape : (175, 1)
# W shape : (21, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 21)
# Haug shape : (175, 22)
# yin shape : (175, 1)
# W shape : (22, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 22)
# Haug shape : (175, 23)
# yin shape : (175, 1)
# W shape : (23, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 23)
# Haug shape : (175, 24)
# yin shape : (175, 1)
# W shape : (24, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 24)
# Haug shape : (175, 25)
# yin shape : (175, 1)
# W shape : (25, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 25)
# Haug shape : (175, 26)
# yin shape : (175, 1)
# W shape : (26, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 26)
# Haug shape : (175, 27)
# yin shape : (175, 1)
# W shape : (27, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 27)
# Haug shape : (175, 28)
# yin shape : (175, 1)
# W shape : (28, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 28)
# Haug shape : (175, 29)
# yin shape : (175, 1)
# W shape : (29, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 29)
# Haug shape : (175, 30)
# yin shape : (175, 1)
# W shape : (30, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 30)
# Haug shape : (175, 31)
# yin shape : (175, 1)
# W shape : (31, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 31)
# Haug shape : (175, 32)
# yin shape : (175, 1)
# W shape : (32, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 32)
# Haug shape : (175, 33)
# yin shape : (175, 1)
# W shape : (33, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 33)
# Haug shape : (175, 34)
# yin shape : (175, 1)
# W shape : (34, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 34)
# Haug shape : (175, 35)
# yin shape : (175, 1)
# W shape : (35, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 35)
# Haug shape : (175, 36)
# yin shape : (175, 1)
# W shape : (36, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 36)
# Haug shape : (175, 37)
# yin shape : (175, 1)
# W shape : (37, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 37)
# Haug shape : (175, 38)
# yin shape : (175, 1)
# W shape : (38, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 38)
# Haug shape : (175, 39)
# yin shape : (175, 1)
# W shape : (39, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 39)
# Haug shape : (175, 40)
# yin shape : (175, 1)
# W shape : (40, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 40)
# Haug shape : (175, 41)
# yin shape : (175, 1)
# W shape : (41, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 41)
# Haug shape : (175, 42)
# yin shape : (175, 1)
# W shape : (42, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 42)
# Haug shape : (175, 43)
# yin shape : (175, 1)
# W shape : (43, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 43)
# Haug shape : (175, 44)
# yin shape : (175, 1)
# W shape : (44, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 44)
# Haug shape : (175, 45)
# yin shape : (175, 1)
# W shape : (45, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 45)
# Haug shape : (175, 46)
# yin shape : (175, 1)
# W shape : (46, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 46)
# Haug shape : (175, 47)
# yin shape : (175, 1)
# W shape : (47, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 47)
# Haug shape : (175, 48)
# yin shape : (175, 1)
# W shape : (48, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 48)
# Haug shape : (175, 49)
# yin shape : (175, 1)
# W shape : (49, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 49)
# Haug shape : (175, 50)
# yin shape : (175, 1)
# W shape : (50, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 50)
# Haug shape : (175, 51)
# yin shape : (175, 1)
# W shape : (51, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 51)
# Haug shape : (175, 52)
# yin shape : (175, 1)
# W shape : (52, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 52)
# Haug shape : (175, 53)
# yin shape : (175, 1)
# W shape : (53, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 53)
# Haug shape : (175, 54)
# yin shape : (175, 1)
# W shape : (54, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 54)
# Haug shape : (175, 55)
# yin shape : (175, 1)
# W shape : (55, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 55)
# Haug shape : (175, 56)
# yin shape : (175, 1)
# W shape : (56, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 56)
# Haug shape : (175, 57)
# yin shape : (175, 1)
# W shape : (57, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 57)
# Haug shape : (175, 58)
# yin shape : (175, 1)
# W shape : (58, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 58)
# Haug shape : (175, 59)
# yin shape : (175, 1)
# W shape : (59, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 59)
# Haug shape : (175, 60)
# yin shape : (175, 1)
# W shape : (60, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 60)
# Haug shape : (175, 61)
# yin shape : (175, 1)
# W shape : (61, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 61)
# Haug shape : (175, 62)
# yin shape : (175, 1)
# W shape : (62, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 62)
# Haug shape : (175, 63)
# yin shape : (175, 1)
# W shape : (63, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 63)
# Haug shape : (175, 64)
# yin shape : (175, 1)
# W shape : (64, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 64)
# Haug shape : (175, 65)
# yin shape : (175, 1)
# W shape : (65, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 65)
# Haug shape : (175, 66)
# yin shape : (175, 1)
# W shape : (66, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 66)
# Haug shape : (175, 67)
# yin shape : (175, 1)
# W shape : (67, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 67)
# Haug shape : (175, 68)
# yin shape : (175, 1)
# W shape : (68, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 68)
# Haug shape : (175, 69)
# yin shape : (175, 1)
# W shape : (69, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 69)
# Haug shape : (175, 70)
# yin shape : (175, 1)
# W shape : (70, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 70)
# Haug shape : (175, 71)
# yin shape : (175, 1)
# W shape : (71, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 71)
# Haug shape : (175, 72)
# yin shape : (175, 1)
# W shape : (72, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 72)
# Haug shape : (175, 73)
# yin shape : (175, 1)
# W shape : (73, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 73)
# Haug shape : (175, 74)
# yin shape : (175, 1)
# W shape : (74, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 74)
# Haug shape : (175, 75)
# yin shape : (175, 1)
# W shape : (75, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 75)
# Haug shape : (175, 76)
# yin shape : (175, 1)
# W shape : (76, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 76)
# Haug shape : (175, 77)
# yin shape : (175, 1)
# W shape : (77, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 77)
# Haug shape : (175, 78)
# yin shape : (175, 1)
# W shape : (78, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 78)
# Haug shape : (175, 79)
# yin shape : (175, 1)
# W shape : (79, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 79)
# Haug shape : (175, 80)
# yin shape : (175, 1)
# W shape : (80, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 80)
# Haug shape : (175, 81)
# yin shape : (175, 1)
# W shape : (81, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 81)
# Haug shape : (175, 82)
# yin shape : (175, 1)
# W shape : (82, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 82)
# Haug shape : (175, 83)
# yin shape : (175, 1)
# W shape : (83, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 83)
# Haug shape : (175, 84)
# yin shape : (175, 1)
# W shape : (84, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 84)
# Haug shape : (175, 85)
# yin shape : (175, 1)
# W shape : (85, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 85)
# Haug shape : (175, 86)
# yin shape : (175, 1)
# W shape : (86, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 86)
# Haug shape : (175, 87)
# yin shape : (175, 1)
# W shape : (87, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 87)
# Haug shape : (175, 88)
# yin shape : (175, 1)
# W shape : (88, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 88)
# Haug shape : (175, 89)
# yin shape : (175, 1)
# W shape : (89, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 89)
# Haug shape : (175, 90)
# yin shape : (175, 1)
# W shape : (90, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 90)
# Haug shape : (175, 91)
# yin shape : (175, 1)
# W shape : (91, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 91)
# Haug shape : (175, 92)
# yin shape : (175, 1)
# W shape : (92, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 92)
# Haug shape : (175, 93)
# yin shape : (175, 1)
# W shape : (93, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 93)
# Haug shape : (175, 94)
# yin shape : (175, 1)
# W shape : (94, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 94)
# Haug shape : (175, 95)
# yin shape : (175, 1)
# W shape : (95, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 95)
# Haug shape : (175, 96)
# yin shape : (175, 1)
# W shape : (96, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 96)
# Haug shape : (175, 97)
# yin shape : (175, 1)
# W shape : (97, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 97)
# Haug shape : (175, 98)
# yin shape : (175, 1)
# W shape : (98, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 98)
# Haug shape : (175, 99)
# yin shape : (175, 1)
# W shape : (99, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 99)
# Haug shape : (175, 100)
# yin shape : (175, 1)
# W shape : (100, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 100)
# Haug shape : (175, 101)
# yin shape : (175, 1)
# W shape : (101, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 101)
# Haug shape : (175, 102)
# yin shape : (175, 1)
# W shape : (102, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 102)
# Haug shape : (175, 103)
# yin shape : (175, 1)
# W shape : (103, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 103)
# Haug shape : (175, 104)
# yin shape : (175, 1)
# W shape : (104, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 104)
# Haug shape : (175, 105)
# yin shape : (175, 1)
# W shape : (105, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 105)
# Haug shape : (175, 106)
# yin shape : (175, 1)
# W shape : (106, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 106)
# Haug shape : (175, 107)
# yin shape : (175, 1)
# W shape : (107, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 107)
# Haug shape : (175, 108)
# yin shape : (175, 1)
# W shape : (108, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 108)
# Haug shape : (175, 109)
# yin shape : (175, 1)
# W shape : (109, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 109)
# Haug shape : (175, 110)
# yin shape : (175, 1)
# W shape : (110, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 110)
# Haug shape : (175, 111)
# yin shape : (175, 1)
# W shape : (111, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 111)
# Haug shape : (175, 112)
# yin shape : (175, 1)
# W shape : (112, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 112)
# Haug shape : (175, 113)
# yin shape : (175, 1)
# W shape : (113, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 113)
# Haug shape : (175, 114)
# yin shape : (175, 1)
# W shape : (114, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 114)
# Haug shape : (175, 115)
# yin shape : (175, 1)
# W shape : (115, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 115)
# Haug shape : (175, 116)
# yin shape : (175, 1)
# W shape : (116, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 116)
# Haug shape : (175, 117)
# yin shape : (175, 1)
# W shape : (117, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 117)
# Haug shape : (175, 118)
# yin shape : (175, 1)
# W shape : (118, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 118)
# Haug shape : (175, 119)
# yin shape : (175, 1)
# W shape : (119, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 119)
# Haug shape : (175, 120)
# yin shape : (175, 1)
# W shape : (120, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 120)
# Haug shape : (175, 121)
# yin shape : (175, 1)
# W shape : (121, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 121)
# Haug shape : (175, 122)
# yin shape : (175, 1)
# W shape : (122, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 122)
# Haug shape : (175, 123)
# yin shape : (175, 1)
# W shape : (123, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 123)
# Haug shape : (175, 124)
# yin shape : (175, 1)
# W shape : (124, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 124)
# Haug shape : (175, 125)
# yin shape : (175, 1)
# W shape : (125, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 125)
# Haug shape : (175, 126)
# yin shape : (175, 1)
# W shape : (126, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 126)
# Haug shape : (175, 127)
# yin shape : (175, 1)
# W shape : (127, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 127)
# Haug shape : (175, 128)
# yin shape : (175, 1)
# W shape : (128, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 128)
# Haug shape : (175, 129)
# yin shape : (175, 1)
# W shape : (129, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 129)
# Haug shape : (175, 130)
# yin shape : (175, 1)
# W shape : (130, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 130)
# Haug shape : (175, 131)
# yin shape : (175, 1)
# W shape : (131, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 131)
# Haug shape : (175, 132)
# yin shape : (175, 1)
# W shape : (132, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 132)
# Haug shape : (175, 133)
# yin shape : (175, 1)
# W shape : (133, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 133)
# Haug shape : (175, 134)
# yin shape : (175, 1)
# W shape : (134, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 134)
# Haug shape : (175, 135)
# yin shape : (175, 1)
# W shape : (135, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 135)
# Haug shape : (175, 136)
# yin shape : (175, 1)
# W shape : (136, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 136)
# Haug shape : (175, 137)
# yin shape : (175, 1)
# W shape : (137, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 137)
# Haug shape : (175, 138)
# yin shape : (175, 1)
# W shape : (138, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 138)
# Haug shape : (175, 139)
# yin shape : (175, 1)
# W shape : (139, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 139)
# Haug shape : (175, 140)
# yin shape : (175, 1)
# W shape : (140, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 140)
# Haug shape : (175, 141)
# yin shape : (175, 1)
# W shape : (141, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 141)
# Haug shape : (175, 142)
# yin shape : (175, 1)
# W shape : (142, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 142)
# Haug shape : (175, 143)
# yin shape : (175, 1)
# W shape : (143, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 143)
# Haug shape : (175, 144)
# yin shape : (175, 1)
# W shape : (144, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 144)
# Haug shape : (175, 145)
# yin shape : (175, 1)
# W shape : (145, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 145)
# Haug shape : (175, 146)
# yin shape : (175, 1)
# W shape : (146, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 146)
# Haug shape : (175, 147)
# yin shape : (175, 1)
# W shape : (147, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 147)
# Haug shape : (175, 148)
# yin shape : (175, 1)
# W shape : (148, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 148)
# Haug shape : (175, 149)
# yin shape : (175, 1)
# W shape : (149, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 149)
# Haug shape : (175, 150)
# yin shape : (175, 1)
# W shape : (150, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 150)
# Haug shape : (175, 151)
# yin shape : (175, 1)
# W shape : (151, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 151)
# Haug shape : (175, 152)
# yin shape : (175, 1)
# W shape : (152, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 152)
# Haug shape : (175, 153)
# yin shape : (175, 1)
# W shape : (153, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 153)
# Haug shape : (175, 154)
# yin shape : (175, 1)
# W shape : (154, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 154)
# Haug shape : (175, 155)
# yin shape : (175, 1)
# W shape : (155, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 155)
# Haug shape : (175, 156)
# yin shape : (175, 1)
# W shape : (156, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 156)
# Haug shape : (175, 157)
# yin shape : (175, 1)
# W shape : (157, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 157)
# Haug shape : (175, 158)
# yin shape : (175, 1)
# W shape : (158, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 158)
# Haug shape : (175, 159)
# yin shape : (175, 1)
# W shape : (159, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 159)
# Haug shape : (175, 160)
# yin shape : (175, 1)
# W shape : (160, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 160)
# Haug shape : (175, 161)
# yin shape : (175, 1)
# W shape : (161, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 161)
# Haug shape : (175, 162)
# yin shape : (175, 1)
# W shape : (162, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 162)
# Haug shape : (175, 163)
# yin shape : (175, 1)
# W shape : (163, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 163)
# Haug shape : (175, 164)
# yin shape : (175, 1)
# W shape : (164, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 164)
# Haug shape : (175, 165)
# yin shape : (175, 1)
# W shape : (165, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 165)
# Haug shape : (175, 166)
# yin shape : (175, 1)
# W shape : (166, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 166)
# Haug shape : (175, 167)
# yin shape : (175, 1)
# W shape : (167, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 167)
# Haug shape : (175, 168)
# yin shape : (175, 1)
# W shape : (168, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 168)
# Haug shape : (175, 169)
# yin shape : (175, 1)
# W shape : (169, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 169)
# Haug shape : (175, 170)
# yin shape : (175, 1)
# W shape : (170, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 170)
# Haug shape : (175, 171)
# yin shape : (175, 1)
# W shape : (171, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 171)
# Haug shape : (175, 172)
# yin shape : (175, 1)
# W shape : (172, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 172)
# Haug shape : (175, 173)
# yin shape : (175, 1)
# W shape : (173, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 173)
# Haug shape : (175, 174)
# yin shape : (175, 1)
# W shape : (174, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 174)
# Haug shape : (175, 175)
# yin shape : (175, 1)
# W shape : (175, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# H shape : (175, 175)
# Haug shape : (175, 176)
# yin shape : (175, 1)
# W shape : (176, 1)
# You're having the error tuple index out of range. So we will change the numer of dimensions...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 5
#       3 lst_param = list()
#       4 for i in range(1, 200, 1):
# ----> 5     kmeans = KMeans(n_clusters = i, random_state = 0, n_init = 'auto').fit(X_train)
#       6     cluster_labels = kmeans.labels_
#       7     cluster_centers = kmeans.cluster_centers_
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1490, in KMeans.fit(self, X, y, sample_weight)
#    1455 """Compute k-means clustering.
#    1456
#    1457 Parameters
#    (...)
#    1479     Fitted estimator.
#    1480 """
#    1481 X = self._validate_data(
#    1482     X,
#    1483     accept_sparse="csr",
#    (...)
#    1487     accept_large_sparse=False,
#    1488 )
# -> 1490 self._check_params_vs_input(X)
#    1492 random_state = check_random_state(self.random_state)
#    1493 sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1431, in KMeans._check_params_vs_input(self, X)
#    1430 def _check_params_vs_input(self, X):
# -> 1431     super()._check_params_vs_input(X, default_n_init=10)
#    1433     self._algorithm = self.algorithm
#    1434     if self._algorithm == "elkan" and self.n_clusters == 1:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:879, in _BaseKMeans._check_params_vs_input(self, X, default_n_init)
#     876 def _check_params_vs_input(self, X, default_n_init=None):
#     877     # n_clusters
#     878     if X.shape[0] < self.n_clusters:
# --> 879         raise ValueError(
#     880             f"n_samples={X.shape[0]} should be >= n_clusters={self.n_clusters}."
#     881         )
#     883     # tol
#     884     self._tol = _tolerance(X, self.tol)
#
# ValueError: n_samples=175 should be >= n_clusters=176.

# %%
idx = np.argmax(lst_error_test)
print(f"Using {lst_param[idx]} radial neurons in the hidden layer the model has the better performance."

# %%
y_test
# Out:
# array([ 0.0839569 ,  0.93218865,  0.09740603,  0.09369478,  0.13462142,
#         0.02105363,  0.03964702, -0.07436244, -0.04201568,  0.14371811,
#        -0.06022265,  0.0435355 , -0.1534082 , -0.0044204 ,  0.37535008,
#         0.1212024 , -0.01029302, -0.15521946,  0.0406797 ,  0.18361989,
#         0.19249998,  0.04732935,  0.05178457, -0.08615239, -0.00980864,
#         0.07542959, -0.00605542, -0.02154063, -0.0131445 , -0.03737993,
#         0.06651387, -0.06310401, -0.13832196, -0.04216474, -0.09728018,
#         0.1363613 ,  0.77255122, -0.02687458, -0.05977921,  1.02899888,
#         0.52551529,  0.00706738, -0.22158121,  0.11084764,  0.06948664,
#         0.13175751,  0.00592102,  0.0147083 ,  0.02327581, -0.01544406,
#         0.02454812,  0.10620589,  0.02900518,  0.00918706, -0.09718894,
#        -0.04317991,  0.01083767,  0.07330324, -0.01184452, -0.0024377 ,
#        -0.09458969,  0.01213987, -0.07994102,  0.13185467,  0.13075095,
#         0.01439286, -0.02888085,  0.05733348,  0.9708163 ,  0.00432662,
#         0.01756063,  0.05228896, -0.03591139,  0.03809871, -0.25201948])

# %%
idx = np.argmax(lst_acc_test)
print(f"The value of K that give us the best performance in test data is : {lst_param[idx]}")
