# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rpy2.robjects as ro
from functools import partial
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr
from rpy2.ipython import html
html.html_rdataframe = partial(html.html_rdataframe, table_class = "docutils")
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(mlbench)
# datasetxor <- mlbench.xor(300)
# XR_datasetxor <- datasetxor$x
# LABELSR_datasetxor<- datasetxor$classes

# %%
from rpy2.robjects import numpy2ri
numpy2ri.activate()
x_df_xor = np.array(ro.r['XR_datasetxor'])
labels_df_xor = np.array(ro.r['LABELSR_datasetxor'])
labels_df_xor[labels_df_xor == 1] = -1
labels_df_xor[labels_df_xor == 2] = 1

# %%
plt.scatter(x_df_xor[:, 0], x_df_xor[:, 1], color = 'black', s = 5)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_df_xor, labels_df_xor, random_state = 0, train_size = 0.7)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 5, random_state = 0, n_init = 'auto').fit(X_train)
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_
p = cluster_centers.shape[0]

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=cluster_labels, cmap='viridis', marker='o', edgecolors='k')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', s=100, label='Cluster Centers')

# Add labels and legend
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KMeans Clustering')
plt.legend()

# Show the plot
plt.show()

# %%
import train_RBF
r = 0.6

# %%
ret_ = train_RBF.trainRBF(X_train, y_train, cluster_centers.shape[0], r = 0.6)
# Out:
# H shape : (210, 5)
# Haug shape : (210, 6)
# yin shape : (210,)
# W shape : (6,)

# %%
ret_[1].shape
X_train[1, :].shape
# Out:
# (2,)

# %%
m = ret_[0]
covi = ret_[1]
r = ret_[2]
W = ret_[3]
H = ret_[4]

# %%
from sklearn.metrics import accuracy_score
lst_acc_test = list()
lst_param = list()

for i in range(1, 200, 1):
    kmeans = KMeans(n_clusters = i, random_state = 0, n_init = 'auto').fit(X_train)
    cluster_labels = kmeans.labels_
    cluster_centers = kmeans.cluster_centers_
    ret_ = train_RBF.trainRBF(X_train, y_train, i, r = 0.6)


    yhat_test = train_RBF.y_RBF(X_test, ret_)
    yhat_test[yhat_test <= -0.5] = -1
    yhat_test[yhat_test > -0.5] = 1
    yhat_train = train_RBF.y_RBF(X_train, ret_)
    yhat_train[yhat_train <= -0.5] = -1
    yhat_train[yhat_train > -0.5] = 1
    lst_acc_test.append(accuracy_score(y_test, yhat_test))
    lst_param.append(i)
lst_acc_test = np.array(lst_acc_test)
lst_param = np.array(lst_param)
# Out:
# H shape : (210, 1)
# Haug shape : (210, 2)
# yin shape : (210,)
# W shape : (2,)
# H shape : (210, 2)
# Haug shape : (210, 3)
# yin shape : (210,)
# W shape : (3,)
# H shape : (210, 3)
# Haug shape : (210, 4)
# yin shape : (210,)
# W shape : (4,)
# H shape : (210, 4)
# Haug shape : (210, 5)
# yin shape : (210,)
# W shape : (5,)
# H shape : (210, 5)
# Haug shape : (210, 6)
# yin shape : (210,)
# W shape : (6,)
# H shape : (210, 6)
# Haug shape : (210, 7)
# yin shape : (210,)
# W shape : (7,)
# H shape : (210, 7)
# Haug shape : (210, 8)
# yin shape : (210,)
# W shape : (8,)
# H shape : (210, 8)
# Haug shape : (210, 9)
# yin shape : (210,)
# W shape : (9,)
# H shape : (210, 9)
# Haug shape : (210, 10)
# yin shape : (210,)
# W shape : (10,)
# H shape : (210, 10)
# Haug shape : (210, 11)
# yin shape : (210,)
# W shape : (11,)
# H shape : (210, 11)
# Haug shape : (210, 12)
# yin shape : (210,)
# W shape : (12,)
# H shape : (210, 12)
# Haug shape : (210, 13)
# yin shape : (210,)
# W shape : (13,)
# H shape : (210, 13)
# Haug shape : (210, 14)
# yin shape : (210,)
# W shape : (14,)
# H shape : (210, 14)
# Haug shape : (210, 15)
# yin shape : (210,)
# W shape : (15,)
# H shape : (210, 15)
# Haug shape : (210, 16)
# yin shape : (210,)
# W shape : (16,)
# H shape : (210, 16)
# Haug shape : (210, 17)
# yin shape : (210,)
# W shape : (17,)
# H shape : (210, 17)
# Haug shape : (210, 18)
# yin shape : (210,)
# W shape : (18,)
# H shape : (210, 18)
# Haug shape : (210, 19)
# yin shape : (210,)
# W shape : (19,)
# H shape : (210, 19)
# Haug shape : (210, 20)
# yin shape : (210,)
# W shape : (20,)
# H shape : (210, 20)
# Haug shape : (210, 21)
# yin shape : (210,)
# W shape : (21,)
# H shape : (210, 21)
# Haug shape : (210, 22)
# yin shape : (210,)
# W shape : (22,)
# H shape : (210, 22)
# Haug shape : (210, 23)
# yin shape : (210,)
# W shape : (23,)
# H shape : (210, 23)
# Haug shape : (210, 24)
# yin shape : (210,)
# W shape : (24,)
# H shape : (210, 24)
# Haug shape : (210, 25)
# yin shape : (210,)
# W shape : (25,)
# H shape : (210, 25)
# Haug shape : (210, 26)
# yin shape : (210,)
# W shape : (26,)
# H shape : (210, 26)
# Haug shape : (210, 27)
# yin shape : (210,)
# W shape : (27,)
# H shape : (210, 27)
# Haug shape : (210, 28)
# yin shape : (210,)
# W shape : (28,)
# H shape : (210, 28)
# Haug shape : (210, 29)
# yin shape : (210,)
# W shape : (29,)
# H shape : (210, 29)
# Haug shape : (210, 30)
# yin shape : (210,)
# W shape : (30,)
# H shape : (210, 30)
# Haug shape : (210, 31)
# yin shape : (210,)
# W shape : (31,)
# H shape : (210, 31)
# Haug shape : (210, 32)
# yin shape : (210,)
# W shape : (32,)
# H shape : (210, 32)
# Haug shape : (210, 33)
# yin shape : (210,)
# W shape : (33,)
# H shape : (210, 33)
# Haug shape : (210, 34)
# yin shape : (210,)
# W shape : (34,)
# H shape : (210, 34)
# Haug shape : (210, 35)
# yin shape : (210,)
# W shape : (35,)
# H shape : (210, 35)
# Haug shape : (210, 36)
# yin shape : (210,)
# W shape : (36,)
# H shape : (210, 36)
# Haug shape : (210, 37)
# yin shape : (210,)
# W shape : (37,)
# H shape : (210, 37)
# Haug shape : (210, 38)
# yin shape : (210,)
# W shape : (38,)
# H shape : (210, 38)
# Haug shape : (210, 39)
# yin shape : (210,)
# W shape : (39,)
# H shape : (210, 39)
# Haug shape : (210, 40)
# yin shape : (210,)
# W shape : (40,)
# H shape : (210, 40)
# Haug shape : (210, 41)
# yin shape : (210,)
# W shape : (41,)
# H shape : (210, 41)
# Haug shape : (210, 42)
# yin shape : (210,)
# W shape : (42,)
# H shape : (210, 42)
# Haug shape : (210, 43)
# yin shape : (210,)
# W shape : (43,)
# H shape : (210, 43)
# Haug shape : (210, 44)
# yin shape : (210,)
# W shape : (44,)
# H shape : (210, 44)
# Haug shape : (210, 45)
# yin shape : (210,)
# W shape : (45,)
# H shape : (210, 45)
# Haug shape : (210, 46)
# yin shape : (210,)
# W shape : (46,)
# H shape : (210, 46)
# Haug shape : (210, 47)
# yin shape : (210,)
# W shape : (47,)
# H shape : (210, 47)
# Haug shape : (210, 48)
# yin shape : (210,)
# W shape : (48,)
# H shape : (210, 48)
# Haug shape : (210, 49)
# yin shape : (210,)
# W shape : (49,)
# H shape : (210, 49)
# Haug shape : (210, 50)
# yin shape : (210,)
# W shape : (50,)
# H shape : (210, 50)
# Haug shape : (210, 51)
# yin shape : (210,)
# W shape : (51,)
# H shape : (210, 51)
# Haug shape : (210, 52)
# yin shape : (210,)
# W shape : (52,)
# H shape : (210, 52)
# Haug shape : (210, 53)
# yin shape : (210,)
# W shape : (53,)
# H shape : (210, 53)
# Haug shape : (210, 54)
# yin shape : (210,)
# W shape : (54,)
# H shape : (210, 54)
# Haug shape : (210, 55)
# yin shape : (210,)
# W shape : (55,)
# H shape : (210, 55)
# Haug shape : (210, 56)
# yin shape : (210,)
# W shape : (56,)
# H shape : (210, 56)
# Haug shape : (210, 57)
# yin shape : (210,)
# W shape : (57,)
# H shape : (210, 57)
# Haug shape : (210, 58)
# yin shape : (210,)
# W shape : (58,)
# H shape : (210, 58)
# Haug shape : (210, 59)
# yin shape : (210,)
# W shape : (59,)
# H shape : (210, 59)
# Haug shape : (210, 60)
# yin shape : (210,)
# W shape : (60,)
# H shape : (210, 60)
# Haug shape : (210, 61)
# yin shape : (210,)
# W shape : (61,)
# H shape : (210, 61)
# Haug shape : (210, 62)
# yin shape : (210,)
# W shape : (62,)
# H shape : (210, 62)
# Haug shape : (210, 63)
# yin shape : (210,)
# W shape : (63,)
# H shape : (210, 63)
# Haug shape : (210, 64)
# yin shape : (210,)
# W shape : (64,)
# H shape : (210, 64)
# Haug shape : (210, 65)
# yin shape : (210,)
# W shape : (65,)
# H shape : (210, 65)
# Haug shape : (210, 66)
# yin shape : (210,)
# W shape : (66,)
# H shape : (210, 66)
# Haug shape : (210, 67)
# yin shape : (210,)
# W shape : (67,)
# H shape : (210, 67)
# Haug shape : (210, 68)
# yin shape : (210,)
# W shape : (68,)
# H shape : (210, 68)
# Haug shape : (210, 69)
# yin shape : (210,)
# W shape : (69,)
# H shape : (210, 69)
# Haug shape : (210, 70)
# yin shape : (210,)
# W shape : (70,)
# H shape : (210, 70)
# Haug shape : (210, 71)
# yin shape : (210,)
# W shape : (71,)
# H shape : (210, 71)
# Haug shape : (210, 72)
# yin shape : (210,)
# W shape : (72,)
# H shape : (210, 72)
# Haug shape : (210, 73)
# yin shape : (210,)
# W shape : (73,)
# H shape : (210, 73)
# Haug shape : (210, 74)
# yin shape : (210,)
# W shape : (74,)
# H shape : (210, 74)
# Haug shape : (210, 75)
# yin shape : (210,)
# W shape : (75,)
# H shape : (210, 75)
# Haug shape : (210, 76)
# yin shape : (210,)
# W shape : (76,)
# H shape : (210, 76)
# Haug shape : (210, 77)
# yin shape : (210,)
# W shape : (77,)
# H shape : (210, 77)
# Haug shape : (210, 78)
# yin shape : (210,)
# W shape : (78,)
# H shape : (210, 78)
# Haug shape : (210, 79)
# yin shape : (210,)
# W shape : (79,)
# H shape : (210, 79)
# Haug shape : (210, 80)
# yin shape : (210,)
# W shape : (80,)
# H shape : (210, 80)
# Haug shape : (210, 81)
# yin shape : (210,)
# W shape : (81,)
# H shape : (210, 81)
# Haug shape : (210, 82)
# yin shape : (210,)
# W shape : (82,)
# H shape : (210, 82)
# Haug shape : (210, 83)
# yin shape : (210,)
# W shape : (83,)
# H shape : (210, 83)
# Haug shape : (210, 84)
# yin shape : (210,)
# W shape : (84,)
# H shape : (210, 84)
# Haug shape : (210, 85)
# yin shape : (210,)
# W shape : (85,)
# H shape : (210, 85)
# Haug shape : (210, 86)
# yin shape : (210,)
# W shape : (86,)
# H shape : (210, 86)
# Haug shape : (210, 87)
# yin shape : (210,)
# W shape : (87,)
# H shape : (210, 87)
# Haug shape : (210, 88)
# yin shape : (210,)
# W shape : (88,)
# H shape : (210, 88)
# Haug shape : (210, 89)
# yin shape : (210,)
# W shape : (89,)
# H shape : (210, 89)
# Haug shape : (210, 90)
# yin shape : (210,)
# W shape : (90,)
# H shape : (210, 90)
# Haug shape : (210, 91)
# yin shape : (210,)
# W shape : (91,)
# H shape : (210, 91)
# Haug shape : (210, 92)
# yin shape : (210,)
# W shape : (92,)
# H shape : (210, 92)
# Haug shape : (210, 93)
# yin shape : (210,)
# W shape : (93,)
# H shape : (210, 93)
# Haug shape : (210, 94)
# yin shape : (210,)
# W shape : (94,)
# H shape : (210, 94)
# Haug shape : (210, 95)
# yin shape : (210,)
# W shape : (95,)
# H shape : (210, 95)
# Haug shape : (210, 96)
# yin shape : (210,)
# W shape : (96,)
# H shape : (210, 96)
# Haug shape : (210, 97)
# yin shape : (210,)
# W shape : (97,)
# H shape : (210, 97)
# Haug shape : (210, 98)
# yin shape : (210,)
# W shape : (98,)
# H shape : (210, 98)
# Haug shape : (210, 99)
# yin shape : (210,)
# W shape : (99,)
# H shape : (210, 99)
# Haug shape : (210, 100)
# yin shape : (210,)
# W shape : (100,)
# H shape : (210, 100)
# Haug shape : (210, 101)
# yin shape : (210,)
# W shape : (101,)
# H shape : (210, 101)
# Haug shape : (210, 102)
# yin shape : (210,)
# W shape : (102,)
# H shape : (210, 102)
# Haug shape : (210, 103)
# yin shape : (210,)
# W shape : (103,)
# H shape : (210, 103)
# Haug shape : (210, 104)
# yin shape : (210,)
# W shape : (104,)
# H shape : (210, 104)
# Haug shape : (210, 105)
# yin shape : (210,)
# W shape : (105,)
# H shape : (210, 105)
# Haug shape : (210, 106)
# yin shape : (210,)
# W shape : (106,)
# H shape : (210, 106)
# Haug shape : (210, 107)
# yin shape : (210,)
# W shape : (107,)
# H shape : (210, 107)
# Haug shape : (210, 108)
# yin shape : (210,)
# W shape : (108,)
# H shape : (210, 108)
# Haug shape : (210, 109)
# yin shape : (210,)
# W shape : (109,)
# H shape : (210, 109)
# Haug shape : (210, 110)
# yin shape : (210,)
# W shape : (110,)
# H shape : (210, 110)
# Haug shape : (210, 111)
# yin shape : (210,)
# W shape : (111,)
# H shape : (210, 111)
# Haug shape : (210, 112)
# yin shape : (210,)
# W shape : (112,)
# H shape : (210, 112)
# Haug shape : (210, 113)
# yin shape : (210,)
# W shape : (113,)
# H shape : (210, 113)
# Haug shape : (210, 114)
# yin shape : (210,)
# W shape : (114,)
# H shape : (210, 114)
# Haug shape : (210, 115)
# yin shape : (210,)
# W shape : (115,)
# H shape : (210, 115)
# Haug shape : (210, 116)
# yin shape : (210,)
# W shape : (116,)
# H shape : (210, 116)
# Haug shape : (210, 117)
# yin shape : (210,)
# W shape : (117,)
# H shape : (210, 117)
# Haug shape : (210, 118)
# yin shape : (210,)
# W shape : (118,)
# H shape : (210, 118)
# Haug shape : (210, 119)
# yin shape : (210,)
# W shape : (119,)
# H shape : (210, 119)
# Haug shape : (210, 120)
# yin shape : (210,)
# W shape : (120,)
# H shape : (210, 120)
# Haug shape : (210, 121)
# yin shape : (210,)
# W shape : (121,)
# H shape : (210, 121)
# Haug shape : (210, 122)
# yin shape : (210,)
# W shape : (122,)
# H shape : (210, 122)
# Haug shape : (210, 123)
# yin shape : (210,)
# W shape : (123,)
# H shape : (210, 123)
# Haug shape : (210, 124)
# yin shape : (210,)
# W shape : (124,)
# H shape : (210, 124)
# Haug shape : (210, 125)
# yin shape : (210,)
# W shape : (125,)
# H shape : (210, 125)
# Haug shape : (210, 126)
# yin shape : (210,)
# W shape : (126,)
# H shape : (210, 126)
# Haug shape : (210, 127)
# yin shape : (210,)
# W shape : (127,)
# H shape : (210, 127)
# Haug shape : (210, 128)
# yin shape : (210,)
# W shape : (128,)
# H shape : (210, 128)
# Haug shape : (210, 129)
# yin shape : (210,)
# W shape : (129,)
# H shape : (210, 129)
# Haug shape : (210, 130)
# yin shape : (210,)
# W shape : (130,)
# H shape : (210, 130)
# Haug shape : (210, 131)
# yin shape : (210,)
# W shape : (131,)
# H shape : (210, 131)
# Haug shape : (210, 132)
# yin shape : (210,)
# W shape : (132,)
# H shape : (210, 132)
# Haug shape : (210, 133)
# yin shape : (210,)
# W shape : (133,)
# H shape : (210, 133)
# Haug shape : (210, 134)
# yin shape : (210,)
# W shape : (134,)
# H shape : (210, 134)
# Haug shape : (210, 135)
# yin shape : (210,)
# W shape : (135,)
# H shape : (210, 135)
# Haug shape : (210, 136)
# yin shape : (210,)
# W shape : (136,)
# H shape : (210, 136)
# Haug shape : (210, 137)
# yin shape : (210,)
# W shape : (137,)
# H shape : (210, 137)
# Haug shape : (210, 138)
# yin shape : (210,)
# W shape : (138,)
# H shape : (210, 138)
# Haug shape : (210, 139)
# yin shape : (210,)
# W shape : (139,)
# H shape : (210, 139)
# Haug shape : (210, 140)
# yin shape : (210,)
# W shape : (140,)
# H shape : (210, 140)
# Haug shape : (210, 141)
# yin shape : (210,)
# W shape : (141,)
# H shape : (210, 141)
# Haug shape : (210, 142)
# yin shape : (210,)
# W shape : (142,)
# H shape : (210, 142)
# Haug shape : (210, 143)
# yin shape : (210,)
# W shape : (143,)
# H shape : (210, 143)
# Haug shape : (210, 144)
# yin shape : (210,)
# W shape : (144,)
# H shape : (210, 144)
# Haug shape : (210, 145)
# yin shape : (210,)
# W shape : (145,)
# H shape : (210, 145)
# Haug shape : (210, 146)
# yin shape : (210,)
# W shape : (146,)
# H shape : (210, 146)
# Haug shape : (210, 147)
# yin shape : (210,)
# W shape : (147,)
# H shape : (210, 147)
# Haug shape : (210, 148)
# yin shape : (210,)
# W shape : (148,)
# H shape : (210, 148)
# Haug shape : (210, 149)
# yin shape : (210,)
# W shape : (149,)
# H shape : (210, 149)
# Haug shape : (210, 150)
# yin shape : (210,)
# W shape : (150,)
# H shape : (210, 150)
# Haug shape : (210, 151)
# yin shape : (210,)
# W shape : (151,)
# H shape : (210, 151)
# Haug shape : (210, 152)
# yin shape : (210,)
# W shape : (152,)
# H shape : (210, 152)
# Haug shape : (210, 153)
# yin shape : (210,)
# W shape : (153,)
# H shape : (210, 153)
# Haug shape : (210, 154)
# yin shape : (210,)
# W shape : (154,)
# H shape : (210, 154)
# Haug shape : (210, 155)
# yin shape : (210,)
# W shape : (155,)
# H shape : (210, 155)
# Haug shape : (210, 156)
# yin shape : (210,)
# W shape : (156,)
# H shape : (210, 156)
# Haug shape : (210, 157)
# yin shape : (210,)
# W shape : (157,)
# H shape : (210, 157)
# Haug shape : (210, 158)
# yin shape : (210,)
# W shape : (158,)
# H shape : (210, 158)
# Haug shape : (210, 159)
# yin shape : (210,)
# W shape : (159,)
# H shape : (210, 159)
# Haug shape : (210, 160)
# yin shape : (210,)
# W shape : (160,)
# H shape : (210, 160)
# Haug shape : (210, 161)
# yin shape : (210,)
# W shape : (161,)
# H shape : (210, 161)
# Haug shape : (210, 162)
# yin shape : (210,)
# W shape : (162,)
# H shape : (210, 162)
# Haug shape : (210, 163)
# yin shape : (210,)
# W shape : (163,)
# H shape : (210, 163)
# Haug shape : (210, 164)
# yin shape : (210,)
# W shape : (164,)
# H shape : (210, 164)
# Haug shape : (210, 165)
# yin shape : (210,)
# W shape : (165,)
# H shape : (210, 165)
# Haug shape : (210, 166)
# yin shape : (210,)
# W shape : (166,)
# H shape : (210, 166)
# Haug shape : (210, 167)
# yin shape : (210,)
# W shape : (167,)
# H shape : (210, 167)
# Haug shape : (210, 168)
# yin shape : (210,)
# W shape : (168,)
# H shape : (210, 168)
# Haug shape : (210, 169)
# yin shape : (210,)
# W shape : (169,)
# H shape : (210, 169)
# Haug shape : (210, 170)
# yin shape : (210,)
# W shape : (170,)
# H shape : (210, 170)
# Haug shape : (210, 171)
# yin shape : (210,)
# W shape : (171,)
# H shape : (210, 171)
# Haug shape : (210, 172)
# yin shape : (210,)
# W shape : (172,)
# H shape : (210, 172)
# Haug shape : (210, 173)
# yin shape : (210,)
# W shape : (173,)
# H shape : (210, 173)
# Haug shape : (210, 174)
# yin shape : (210,)
# W shape : (174,)
# H shape : (210, 174)
# Haug shape : (210, 175)
# yin shape : (210,)
# W shape : (175,)
# H shape : (210, 175)
# Haug shape : (210, 176)
# yin shape : (210,)
# W shape : (176,)
# H shape : (210, 176)
# Haug shape : (210, 177)
# yin shape : (210,)
# W shape : (177,)
# H shape : (210, 177)
# Haug shape : (210, 178)
# yin shape : (210,)
# W shape : (178,)
# H shape : (210, 178)
# Haug shape : (210, 179)
# yin shape : (210,)
# W shape : (179,)
# H shape : (210, 179)
# Haug shape : (210, 180)
# yin shape : (210,)
# W shape : (180,)
# H shape : (210, 180)
# Haug shape : (210, 181)
# yin shape : (210,)
# W shape : (181,)
# H shape : (210, 181)
# Haug shape : (210, 182)
# yin shape : (210,)
# W shape : (182,)
# H shape : (210, 182)
# Haug shape : (210, 183)
# yin shape : (210,)
# W shape : (183,)
# H shape : (210, 183)
# Haug shape : (210, 184)
# yin shape : (210,)
# W shape : (184,)
# H shape : (210, 184)
# Haug shape : (210, 185)
# yin shape : (210,)
# W shape : (185,)
# H shape : (210, 185)
# Haug shape : (210, 186)
# yin shape : (210,)
# W shape : (186,)
# H shape : (210, 186)
# Haug shape : (210, 187)
# yin shape : (210,)
# W shape : (187,)
# H shape : (210, 187)
# Haug shape : (210, 188)
# yin shape : (210,)
# W shape : (188,)
# H shape : (210, 188)
# Haug shape : (210, 189)
# yin shape : (210,)
# W shape : (189,)
# H shape : (210, 189)
# Haug shape : (210, 190)
# yin shape : (210,)
# W shape : (190,)
# H shape : (210, 190)
# Haug shape : (210, 191)
# yin shape : (210,)
# W shape : (191,)
# H shape : (210, 191)
# Haug shape : (210, 192)
# yin shape : (210,)
# W shape : (192,)
# H shape : (210, 192)
# Haug shape : (210, 193)
# yin shape : (210,)
# W shape : (193,)
# H shape : (210, 193)
# Haug shape : (210, 194)
# yin shape : (210,)
# W shape : (194,)
# H shape : (210, 194)
# Haug shape : (210, 195)
# yin shape : (210,)
# W shape : (195,)
# H shape : (210, 195)
# Haug shape : (210, 196)
# yin shape : (210,)
# W shape : (196,)
# H shape : (210, 196)
# Haug shape : (210, 197)
# yin shape : (210,)
# W shape : (197,)
# H shape : (210, 197)
# Haug shape : (210, 198)
# yin shape : (210,)
# W shape : (198,)
# H shape : (210, 198)
# Haug shape : (210, 199)
# yin shape : (210,)
# W shape : (199,)
# H shape : (210, 199)
# Haug shape : (210, 200)
# yin shape : (210,)
# W shape : (200,)

# %%
idx = np.argmax(lst_acc_test)
print(f"The value of K that give us the best performance in test data is : {lst_param[idx]}")
# Out:
# The value of K that give us the best performance in test data is : 74

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_train, yhat_train)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
#plt.title(' TRAIN DATA RESULT')
cm_display.plot()
plt.show()

# %%
from sklearn import metrics
confusion_matrix_2 = metrics.confusion_matrix(y_test, yhat_test)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_2, display_labels = [False, True])
#plt.title(' TEST DATA RESULT')
cm_display.plot()
plt.show()

# %%
# Assuming m, r, p, W, train_RBF are defined elsewhere
seqx1x2 = np.linspace(start = -1.5 , stop = 1.5, num = 300)
np_grid = seqx1x2.shape[0]
shape = (np_grid, np_grid)
MZ = np.zeros(shape)

# Criando o grid de valores (n x n)
for i in range(np_grid):
    for j in range(np_grid):
        x1 = seqx1x2[i]
        x2 = seqx1x2[j]
        x1x2 = np.column_stack((x1, x2))
        N = x1x2.shape[0]  # Number of samples
        n = x1x2.shape[1]  # Input dimension

        yhat = train_RBF.y_RBF(x1x2, ret_)
        MZ[i, j] = yhat[0]
print("Completed")
# Out:
# Completed

# %%
labels_df_xor = labels_df_xor.reshape(-1, 1)
mat_plot = np.concatenate((x_df_xor, labels_df_xor), axis = 1)
index_sort = 2
sorted_indices = np.argsort(mat_plot[:, index_sort])
mat_plot = mat_plot[sorted_indices]
x1_points = mat_plot[: 150, 0 : 2]
x2_points = mat_plot[150 :, 0 : 2]

# %%
plt.contour(seqx1x2, seqx1x2, MZ,  levels = 1)
plt.scatter(x1_points[:, 0], x1_points[:, 1], color = 'red', label = 'data1', s = 5)
plt.scatter(x2_points[:, 0], x2_points[:, 1], color = 'blue', label = 'data2', s = 5)
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Contour Plot')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.show()

# %%
# Assuming m, r, p, W, train_RBF are defined elsewhere
seqx1x2 = np.linspace(start = -1.5 , stop = 1.5, num = 300)
np_grid = seqx1x2.shape[0]
shape = (np_grid, np_grid)
MZ = np.zeros(shape)

# Criando o grid de valores (n x n)
for i in range(np_grid):
    for j in range(np_grid):
        x1 = seqx1x2[i]
        x2 = seqx1x2[j]
        x1x2 = np.column_stack((x1, x2))
        N = x1x2.shape[0]  # Number of samples
        n = x1x2.shape[1]  # Input dimension

        yhat = train_RBF.y_RBF(x1x2, ret_)
        MZ[i, j] = yhat[0]
print("Completed")
# Out:
# Completed

# %%
labels_df_xor = labels_df_xor.reshape(-1, 1)
mat_plot = np.concatenate((x_df_xor, labels_df_xor), axis = 1)
index_sort = 2
sorted_indices = np.argsort(mat_plot[:, index_sort])
mat_plot = mat_plot[sorted_indices]
x1_points = mat_plot[: 150, 0 : 2]
x2_points = mat_plot[150 :, 0 : 2]

# %%
plt.contour(seqx1x2, seqx1x2, MZ,  levels = 1)
plt.scatter(x1_points[:, 0], x1_points[:, 1], color = 'red', label = 'data1', s = 5)
plt.scatter(x2_points[:, 0], x2_points[:, 1], color = 'blue', label = 'data2', s = 5)
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Contour Plot')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.show()

# %%
import train_RBF
kmeans = KMeans(n_clusters = 200, random_state = 0, n_init = 'auto').fit(X_train)
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_
ret_ = train_RBF.trainRBFreg(X_train, y_train, p = cluster_centers.shape[0], r = 0.6, lam = 0.1)
# Out:
# H shape : (210, 200)
# Haug shape : (210, 201)
# yin shape : (210,)
# W shape : (201,)

# %%
# Assuming m, r, p, W, train_RBF are defined elsewhere
seqx1x2 = np.linspace(start = -1.5 , stop = 1.5, num = 300)
np_grid = seqx1x2.shape[0]
shape = (np_grid, np_grid)
MZ = np.zeros(shape)

# Criando o grid de valores (n x n)
for i in range(np_grid):
    for j in range(np_grid):
        x1 = seqx1x2[i]
        x2 = seqx1x2[j]
        x1x2 = np.column_stack((x1, x2))
        N = x1x2.shape[0]  # Number of samples
        n = x1x2.shape[1]  # Input dimension

        yhat = train_RBF.y_RBF(x1x2, ret_)
        MZ[i, j] = yhat[0]
print("Completed")

# %%
labels_df_xor = labels_df_xor.reshape(-1, 1)
mat_plot = np.concatenate((x_df_xor, labels_df_xor), axis = 1)
index_sort = 2
sorted_indices = np.argsort(mat_plot[:, index_sort])
mat_plot = mat_plot[sorted_indices]
x1_points = mat_plot[: 150, 0 : 2]
x2_points = mat_plot[150 :, 0 : 2]

# %%
plt.contour(seqx1x2, seqx1x2, MZ,  levels = 1)
plt.scatter(x1_points[:, 0], x1_points[:, 1], color = 'red', label = 'data1', s = 5)
plt.scatter(x2_points[:, 0], x2_points[:, 1], color = 'blue', label = 'data2', s = 5)
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Contour Plot')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.show()
