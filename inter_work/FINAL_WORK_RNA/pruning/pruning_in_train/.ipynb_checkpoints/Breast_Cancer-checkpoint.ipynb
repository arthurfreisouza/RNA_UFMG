# %%
import pandas as pd
import numpy as np
import techniques
import matplotlib.pyplot as plt

# %%
bcancer_df = pd.read_csv("breast_cancer.csv")
bcancer_df = bcancer_df.sample(frac=1).reset_index(drop=True)
bcancer_df
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    8711561         B        11.75         20.18           76.10      419.8
# 1      87163         M        13.43         19.63           85.84      565.4
# 2     892189         M        11.76         18.14           75.00      431.1
# 3     906024         B        12.70         12.17           80.88      495.0
# 4     913102         B        14.64         16.85           94.21      666.0
# ..       ...       ...          ...           ...             ...        ...
# 564   857156         B        13.49         22.30           86.91      561.0
# 565     8913         B        12.89         13.12           81.89      515.9
# 566   855625         M        19.07         24.81          128.30     1104.0
# 567   874373         B        11.71         17.19           74.68      420.3
# 568    86211         B        12.18         17.84           77.79      451.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.10890           0.11410         0.06843              0.03738
# 1            0.09048           0.06288         0.05858              0.03438
# 2            0.09968           0.05914         0.02685              0.03515
# 3            0.08785           0.05794         0.02360              0.02402
# 4            0.08641           0.06698         0.05192              0.02791
# ..               ...               ...             ...                  ...
# 564          0.08752           0.07698         0.04751              0.03384
# 565          0.06955           0.03729         0.02260              0.01171
# 566          0.09081           0.21900         0.21070              0.09961
# 567          0.09774           0.06141         0.03809              0.03239
# 568          0.10450           0.07057         0.02490              0.02941
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          26.21            88.91       543.9           0.13580
# 1    ...          29.87           116.60       993.6           0.14010
# 2    ...          23.39            85.10       553.6           0.11370
# 3    ...          16.92            88.12       566.9           0.13140
# 4    ...          25.44           106.00       831.0           0.11420
# ..   ...            ...              ...         ...               ...
# 564  ...          31.82            99.00       698.8           0.11620
# 565  ...          15.54            87.40       577.0           0.09616
# 566  ...          33.17           177.40      1651.0           0.12470
# 567  ...          21.39            84.42       521.5           0.13230
# 568  ...          20.92            82.14       495.2           0.11400
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.18920          0.19560               0.07909          0.3168
# 1              0.15460          0.26440               0.11600          0.2884
# 2              0.07974          0.06120               0.07160          0.1978
# 3              0.16070          0.09385               0.08224          0.2775
# 4              0.20700          0.24370               0.07828          0.2455
# ..                 ...              ...                   ...             ...
# 564            0.17110          0.22820               0.12820          0.2871
# 565            0.11470          0.11860               0.05366          0.2309
# 566            0.74440          0.72420               0.24930          0.4670
# 567            0.10400          0.15210               0.10990          0.2572
# 568            0.09358          0.04980               0.05882          0.2227
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.07987          NaN
# 1                    0.07371          NaN
# 2                    0.06915          NaN
# 3                    0.09464          NaN
# 4                    0.06596          NaN
# ..                       ...          ...
# 564                  0.06917          NaN
# 565                  0.06915          NaN
# 566                  0.10380          NaN
# 567                  0.07097          NaN
# 568                  0.07376          NaN
#
# [569 rows x 33 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
bcancer_df['diagnosis'] = np.where(bcancer_df['diagnosis'] == 'M', 1, -1)
column_sels = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'texture_worst', 'perimeter_worst', 'area_worst']
bcancer_df.loc[:, column_sels] = scaler.fit_transform(bcancer_df.loc[:, column_sels])
bcancer_df
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    8711561         -1    -0.675185      0.207191       -0.653649  -0.668618
# 1      87163          1    -0.198041      0.079202       -0.252456  -0.254516
# 2     892189          1    -0.672344     -0.267531       -0.698958  -0.636479
# 3     906024         -1    -0.405371     -1.656790       -0.456760  -0.454741
# 4     913102         -1     0.145616     -0.567723        0.092306   0.031601
# ..       ...        ...          ...           ...             ...        ...
# 564   857156         -1    -0.181000      0.700529       -0.208383  -0.267030
# 565     8913         -1    -0.351408     -1.435719       -0.415157  -0.395299
# 566   855625          1     1.403799      1.284623        1.496480   1.277317
# 567   874373         -1    -0.686545     -0.488602       -0.712139  -0.667195
# 568    86211         -1    -0.553058     -0.337343       -0.584037  -0.579597
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.10890           0.11410         0.06843              0.03738
# 1            0.09048           0.06288         0.05858              0.03438
# 2            0.09968           0.05914         0.02685              0.03515
# 3            0.08785           0.05794         0.02360              0.02402
# 4            0.08641           0.06698         0.05192              0.02791
# ..               ...               ...             ...                  ...
# 564          0.08752           0.07698         0.04751              0.03384
# 565          0.06955           0.03729         0.02260              0.01171
# 566          0.09081           0.21900         0.21070              0.09961
# 567          0.09774           0.06141         0.03809              0.03239
# 568          0.10450           0.07057         0.02490              0.02941
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...       0.086759        -0.546606   -0.591860           0.13580
# 1    ...       0.682768         0.278164    0.198674           0.14010
# 2    ...      -0.372460        -0.660090   -0.574808           0.11370
# 3    ...      -1.426059        -0.570137   -0.551428           0.13140
# 4    ...      -0.038630        -0.037566   -0.087163           0.11420
# ..   ...            ...              ...         ...               ...
# 564  ...       1.000313        -0.246067   -0.319559           0.11620
# 565  ...      -1.650784        -0.591583   -0.533673           0.09616
# 566  ...       1.220152         2.089143    1.354326           0.12470
# 567  ...      -0.698148        -0.680345   -0.631237           0.13230
# 568  ...      -0.774684        -0.748256   -0.677470           0.11400
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.18920          0.19560               0.07909          0.3168
# 1              0.15460          0.26440               0.11600          0.2884
# 2              0.07974          0.06120               0.07160          0.1978
# 3              0.16070          0.09385               0.08224          0.2775
# 4              0.20700          0.24370               0.07828          0.2455
# ..                 ...              ...                   ...             ...
# 564            0.17110          0.22820               0.12820          0.2871
# 565            0.11470          0.11860               0.05366          0.2309
# 566            0.74440          0.72420               0.24930          0.4670
# 567            0.10400          0.15210               0.10990          0.2572
# 568            0.09358          0.04980               0.05882          0.2227
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.07987          NaN
# 1                    0.07371          NaN
# 2                    0.06915          NaN
# 3                    0.09464          NaN
# 4                    0.06596          NaN
# ..                       ...          ...
# 564                  0.06917          NaN
# 565                  0.06915          NaN
# 566                  0.10380          NaN
# 567                  0.07097          NaN
# 568                  0.07376          NaN
#
# [569 rows x 33 columns]

# %%
y = np.array(bcancer_df['diagnosis'])
col_sel = bcancer_df.columns[2 : -1]
x = np.array(bcancer_df[col_sel])

# %%
#p_n = int(await input("Type how many neurons do you want to use in the hidden layer : "))
p_n = 100
keep_val = np.arange(start = 0.45, stop = 1, step = 0.1)
best_keep, best_acc, arr_ret = techniques.grid_searchCV_pruning(xin = x, yin = y, p = p_n, keep_rate = keep_val, CV_groups = 15, classification = True)
# Out:
# The model with best accuracy has the mean accuracy : 0.5437201907790143
# The model parameters with best accuracy is using keep_rate : 0.55

# %%
x_plot = np.arange(start = 0.45, stop = keep_val[keep_val.shape[0] -1], step = 0.1)
plt.plot(x_plot, arr_ret, color = 'black', label = 'accuracy vs keep_rate')
plt.title('accuracy vs keep_rate')
plt.xlabel('keep_rate')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 0, train_size = 0.8)

# %%
np.unique(y_test, return_counts = True)
#y_test
# Out:
# (array([-1,  1]), array([64, 50]))

# %%
ret = techniques.train_ELM_PRUNING(xin = X_train, yin = y_train, p = p_n, keep_rate = best_keep, control = True)
best_w = ret[0]
best_h = ret[1]
best_z = ret[2]
err_vec = ret[3]

# %%
x_plot = np.arange(start = 0, stop = err_vec.shape[0], step = 1)
plt.plot(x_plot, err_vec, color = 'black', label = 'error vs epoch')
plt.title('error vs epoch')
plt.xlabel('epoch')
plt.ylabel('error')
plt.legend()
plt.show()

# %%
from sklearn import metrics
y_pred = techniques.test_ELM(xin = X_test, Z = best_z, W = best_w, classification = True, control = True).reshape(-1, )
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
