# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(100, 1)
y = 4 + (5*X) + 2*np.random.randn(100, 1)

# %%
plt.scatter(X, y, color = 'blue', s = 5)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
X_vals = np.linspace(start = -3, stop = 3, num = 100).reshape(-1, 1)
y_vals = reg.predict(X_vals)
plt.scatter(X, y, color = 'blue', label = 'Data', s = 5)
plt.plot(X_vals, y_vals, color = 'red', label = 'Linear Regression')
plt.show()
